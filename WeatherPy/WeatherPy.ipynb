# %%
#set the path
import sys
sys.path.append('C:/Users/ferou/OneDrive/Desktop/python-api-challenge/api_keys.py')
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import api_keys
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 602

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")
for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | fuvahmulah.
# City not found...skipping fuvahmulah.
# Processing Record 1  of Set 1 | zhangjiakou.
# Processing Record 2  of Set 1 | muzayri'.
# City not found...skipping muzayri'.
# Processing Record 3  of Set 1 | clorinda.
# Processing Record 4  of Set 1 | papatowai.
# Processing Record 5  of Set 1 | adamstown.
# Processing Record 6  of Set 1 | yellowknife.
# Processing Record 7  of Set 1 | grytviken.
# Processing Record 8  of Set 1 | weno.
# Processing Record 9  of Set 1 | colby.
# Processing Record 10  of Set 1 | alice springs.
# Processing Record 11  of Set 1 | klaksvik.
# Processing Record 12  of Set 1 | port-aux-francais.
# Processing Record 13  of Set 1 | tranovaho.
# City not found...skipping tranovaho.
# Processing Record 14  of Set 1 | ushuaia.
# Processing Record 15  of Set 1 | novodvinsk.
# Processing Record 16  of Set 1 | kabare.
# Processing Record 17  of Set 1 | invercargill.
# Processing Record 18  of Set 1 | waitangi.
# Processing Record 19  of Set 1 | zemio.
# Processing Record 20  of Set 1 | saint-philippe.
# Processing Record 21  of Set 1 | punta arenas.
# Processing Record 22  of Set 1 | margaret river.
# Processing Record 23  of Set 1 | ambon.
# Processing Record 24  of Set 1 | annau.
# Processing Record 25  of Set 1 | thompson.
# Processing Record 26  of Set 1 | parkes.
# Processing Record 27  of Set 1 | bardai.
# Processing Record 28  of Set 1 | odesskoye.
# Processing Record 29  of Set 1 | ust-nera.
# Processing Record 30  of Set 1 | edinburgh of the seven seas.
# Processing Record 31  of Set 1 | broken hill.
# Processing Record 32  of Set 1 | murghob.
# Processing Record 33  of Set 1 | sedrata.
# Processing Record 34  of Set 1 | bethel.
# Processing Record 35  of Set 1 | sennoy.
# Processing Record 36  of Set 1 | whitehorse.
# Processing Record 37  of Set 1 | wailua homesteads.
# Processing Record 38  of Set 1 | sao joao da barra.
# Processing Record 39  of Set 1 | williamston.
# Processing Record 40  of Set 1 | tralee.
# Processing Record 41  of Set 1 | colonia.
# Processing Record 42  of Set 1 | birecik.
# Processing Record 43  of Set 1 | sitka.
# Processing Record 44  of Set 1 | tangalle.
# Processing Record 45  of Set 1 | cacapava do sul.
# Processing Record 46  of Set 1 | holualoa.
# Processing Record 47  of Set 1 | miri.
# Processing Record 48  of Set 1 | qaqortoq.
# Processing Record 49  of Set 1 | vila velha.
# Processing Record 0  of Set 2 | kodiak.
# Processing Record 1  of Set 2 | taiohae.
# City not found...skipping taiohae.
# Processing Record 2  of Set 2 | georgetown.
# Processing Record 3  of Set 2 | arraial do cabo.
# Processing Record 4  of Set 2 | port mathurin.
# Processing Record 5  of Set 2 | 'ohonua.
# City not found...skipping 'ohonua.
# Processing Record 6  of Set 2 | manay.
# Processing Record 7  of Set 2 | puerto natales.
# Processing Record 8  of Set 2 | klyuchi.
# Processing Record 9  of Set 2 | zangguy.
# City not found...skipping zangguy.
# Processing Record 10  of Set 2 | pangody.
# Processing Record 11  of Set 2 | suntar.
# Processing Record 12  of Set 2 | touros.
# Processing Record 13  of Set 2 | ancud.
# Processing Record 14  of Set 2 | tabas.
# Processing Record 15  of Set 2 | atafu village.
# Processing Record 16  of Set 2 | tulum.
# Processing Record 17  of Set 2 | we.
# City not found...skipping we.
# Processing Record 18  of Set 2 | hawaiian paradise park.
# Processing Record 19  of Set 2 | aoulef.
# Processing Record 20  of Set 2 | iqaluit.
# Processing Record 21  of Set 2 | virac.
# Processing Record 22  of Set 2 | port elizabeth.
# Processing Record 23  of Set 2 | aasiaat.
# Processing Record 24  of Set 2 | utrik.
# Processing Record 25  of Set 2 | pisco.
# Processing Record 26  of Set 2 | carnarvon.
# Processing Record 27  of Set 2 | tiksi.
# Processing Record 28  of Set 2 | longyearbyen.
# Processing Record 29  of Set 2 | lihue.
# Processing Record 30  of Set 2 | fortuna.
# Processing Record 31  of Set 2 | selfoss.
# Processing Record 32  of Set 2 | salinopolis.
# Processing Record 33  of Set 2 | rawson.
# Processing Record 34  of Set 2 | mumford.
# Processing Record 35  of Set 2 | lompoc.
# Processing Record 36  of Set 2 | lebu.
# Processing Record 37  of Set 2 | blackmans bay.
# Processing Record 38  of Set 2 | marka.
# Processing Record 39  of Set 2 | ebon.
# Processing Record 40  of Set 2 | ambovombe.
# Processing Record 41  of Set 2 | erenhot.
# Processing Record 42  of Set 2 | howard springs.
# Processing Record 43  of Set 2 | constantia.
# Processing Record 44  of Set 2 | behshahr.
# Processing Record 45  of Set 2 | sechura.
# Processing Record 46  of Set 2 | port blair.
# Processing Record 47  of Set 2 | kuta.
# Processing Record 48  of Set 2 | gamba.
# Processing Record 49  of Set 2 | hilo.
# Processing Record 0  of Set 3 | nizhniy lomov.
# Processing Record 1  of Set 3 | mokolo.
# Processing Record 2  of Set 3 | la ronge.
# Processing Record 3  of Set 3 | ascencion de guarayos.
# City not found...skipping ascencion de guarayos.
# Processing Record 4  of Set 3 | cooma.
# Processing Record 5  of Set 3 | gamboru.
# Processing Record 6  of Set 3 | sicuani.
# Processing Record 7  of Set 3 | kailua-kona.
# Processing Record 8  of Set 3 | inhambane.
# Processing Record 9  of Set 3 | st. john's.
# Processing Record 10  of Set 3 | cristalina.
# Processing Record 11  of Set 3 | ilulissat.
# Processing Record 12  of Set 3 | port alberni.
# Processing Record 13  of Set 3 | fort st. john.
# Processing Record 14  of Set 3 | west island.
# Processing Record 15  of Set 3 | puerto ayora.
# Processing Record 16  of Set 3 | udachny.
# Processing Record 17  of Set 3 | new norfolk.
# Processing Record 18  of Set 3 | college.
# Processing Record 19  of Set 3 | stanley.
# Processing Record 20  of Set 3 | nema.
# Processing Record 21  of Set 3 | swift current.
# Processing Record 22  of Set 3 | bilibino.
# Processing Record 23  of Set 3 | san-pedro.
# Processing Record 24  of Set 3 | iskateley.
# Processing Record 25  of Set 3 | zapatoca.
# Processing Record 26  of Set 3 | nelson bay.
# Processing Record 27  of Set 3 | jamestown.
# Processing Record 28  of Set 3 | bredasdorp.
# Processing Record 29  of Set 3 | amga.
# Processing Record 30  of Set 3 | yinchuan.
# Processing Record 31  of Set 3 | tanki leendert.
# City not found...skipping tanki leendert.
# Processing Record 32  of Set 3 | manicore.
# Processing Record 33  of Set 3 | sale.
# Processing Record 34  of Set 3 | hotan.
# Processing Record 35  of Set 3 | ust'-barguzin.
# Processing Record 36  of Set 3 | maintirano.
# Processing Record 37  of Set 3 | siwa oasis.
# Processing Record 38  of Set 3 | kokshetau.
# Processing Record 39  of Set 3 | paredon.
# Processing Record 40  of Set 3 | kapuskasing.
# Processing Record 41  of Set 3 | newman.
# Processing Record 42  of Set 3 | kenai.
# Processing Record 43  of Set 3 | queenstown.
# Processing Record 44  of Set 3 | kushk.
# Processing Record 45  of Set 3 | gadzhiyevo.
# Processing Record 46  of Set 3 | vila franca do campo.
# Processing Record 47  of Set 3 | albany.
# Processing Record 48  of Set 3 | kristiansund.
# Processing Record 49  of Set 3 | coxen hole.
# Processing Record 0  of Set 4 | isafjordur.
# Processing Record 1  of Set 4 | bengkulu.
# Processing Record 2  of Set 4 | thinadhoo.
# Processing Record 3  of Set 4 | keflavik.
# Processing Record 4  of Set 4 | vilyuysk.
# Processing Record 5  of Set 4 | puerto deseado.
# Processing Record 6  of Set 4 | chamical.
# Processing Record 7  of Set 4 | polyarnyy.
# Processing Record 8  of Set 4 | nar'yan-mar.
# Processing Record 9  of Set 4 | east london.
# Processing Record 10  of Set 4 | xiongzhou.
# Processing Record 11  of Set 4 | francavilla al mare.
# Processing Record 12  of Set 4 | minas de marcona.
# Processing Record 13  of Set 4 | olonkinbyen.
# Processing Record 14  of Set 4 | saltillo.
# Processing Record 15  of Set 4 | sandur.
# Processing Record 16  of Set 4 | hermanus.
# Processing Record 17  of Set 4 | pyt-yakh.
# Processing Record 18  of Set 4 | vorgashor.
# Processing Record 19  of Set 4 | ribeira grande.
# Processing Record 20  of Set 4 | dudinka.
# Processing Record 21  of Set 4 | bamboo flat.
# Processing Record 22  of Set 4 | talnakh.
# Processing Record 23  of Set 4 | san patricio.
# Processing Record 24  of Set 4 | hasaki.
# Processing Record 25  of Set 4 | severo-yeniseyskiy.
# Processing Record 26  of Set 4 | mana.
# Processing Record 27  of Set 4 | vingt cinq.
# City not found...skipping vingt cinq.
# Processing Record 28  of Set 4 | villa gesell.
# Processing Record 29  of Set 4 | zaragoza.
# Processing Record 30  of Set 4 | alotau.
# City not found...skipping alotau.
# Processing Record 31  of Set 4 | katsuura.
# Processing Record 32  of Set 4 | cairns city.
# City not found...skipping cairns city.
# Processing Record 33  of Set 4 | saratamata.
# City not found...skipping saratamata.
# Processing Record 34  of Set 4 | hithadhoo.
# Processing Record 35  of Set 4 | mokhsogollokh.
# Processing Record 36  of Set 4 | malango.
# Processing Record 37  of Set 4 | kavaratti.
# Processing Record 38  of Set 4 | mundri.
# Processing Record 39  of Set 4 | vadso.
# Processing Record 40  of Set 4 | tura.
# Processing Record 41  of Set 4 | ranavav.
# Processing Record 42  of Set 4 | vilyuchinsk.
# Processing Record 43  of Set 4 | tazacorte.
# Processing Record 44  of Set 4 | ola.
# Processing Record 45  of Set 4 | moratalla.
# Processing Record 46  of Set 4 | brookings.
# Processing Record 47  of Set 4 | malvan.
# Processing Record 48  of Set 4 | pico truncado.
# Processing Record 49  of Set 4 | enewetak.
# Processing Record 0  of Set 5 | bonny.
# Processing Record 1  of Set 5 | ciudad lazaro cardenas.
# Processing Record 2  of Set 5 | thame.
# Processing Record 3  of Set 5 | port alfred.
# Processing Record 4  of Set 5 | paraibano.
# Processing Record 5  of Set 5 | punta gorda.
# Processing Record 6  of Set 5 | necochea.
# Processing Record 7  of Set 5 | baardheere.
# Processing Record 8  of Set 5 | viedma.
# Processing Record 9  of Set 5 | la quiaca.
# Processing Record 10  of Set 5 | avarua.
# Processing Record 11  of Set 5 | livadeia.
# Processing Record 12  of Set 5 | kem'.
# Processing Record 13  of Set 5 | shahrak-e pabedana.
# City not found...skipping shahrak-e pabedana.
# Processing Record 14  of Set 5 | batyrevo.
# Processing Record 15  of Set 5 | manado.
# Processing Record 16  of Set 5 | falam.
# Processing Record 17  of Set 5 | afaahiti.
# Processing Record 18  of Set 5 | velykyy bereznyy.
# City not found...skipping velykyy bereznyy.
# Processing Record 19  of Set 5 | bandarbeyla.
# Processing Record 20  of Set 5 | hovd.
# Processing Record 21  of Set 5 | yuzhne.
# Processing Record 22  of Set 5 | diok'nisi.
# Processing Record 23  of Set 5 | yagry.
# City not found...skipping yagry.
# Processing Record 24  of Set 5 | dondo.
# Processing Record 25  of Set 5 | opuwo.
# Processing Record 26  of Set 5 | nova sintra.
# Processing Record 27  of Set 5 | tobelo.
# Processing Record 28  of Set 5 | tual.
# Processing Record 29  of Set 5 | rovaniemi.
# Processing Record 30  of Set 5 | paradip garh.
# Processing Record 31  of Set 5 | pervomayskoye.
# Processing Record 32  of Set 5 | boyolangu.
# Processing Record 33  of Set 5 | suva.
# Processing Record 34  of Set 5 | carutapera.
# Processing Record 35  of Set 5 | at taj.
# Processing Record 36  of Set 5 | la passe.
# Processing Record 37  of Set 5 | port lincoln.
# Processing Record 38  of Set 5 | mont-tremblant.
# Processing Record 39  of Set 5 | hayma'.
# City not found...skipping hayma'.
# Processing Record 40  of Set 5 | corner brook.
# Processing Record 41  of Set 5 | igrim.
# Processing Record 42  of Set 5 | bonthe.
# Processing Record 43  of Set 5 | inyati.
# Processing Record 44  of Set 5 | tazovsky.
# Processing Record 45  of Set 5 | oroqen zizhiqi.
# Processing Record 46  of Set 5 | beruniy.
# Processing Record 47  of Set 5 | ixtapa.
# Processing Record 48  of Set 5 | nemuro.
# Processing Record 49  of Set 5 | san sebastian de la gomera.
# Processing Record 0  of Set 6 | codrington.
# Processing Record 1  of Set 6 | campos altos.
# Processing Record 2  of Set 6 | cannonvale.
# Processing Record 3  of Set 6 | anadyr.
# Processing Record 4  of Set 6 | tchibanga.
# Processing Record 5  of Set 6 | puerto princesa.
# Processing Record 6  of Set 6 | mournies.
# Processing Record 7  of Set 6 | woodbridge.
# Processing Record 8  of Set 6 | forest.
# Processing Record 9  of Set 6 | badger.
# Processing Record 10  of Set 6 | san pedro pochutla.
# Processing Record 11  of Set 6 | lockwood.
# Processing Record 12  of Set 6 | damongo.
# City not found...skipping damongo.
# Processing Record 13  of Set 6 | askoy.
# Processing Record 14  of Set 6 | holmsund.
# Processing Record 15  of Set 6 | karratha.
# Processing Record 16  of Set 6 | bati.
# Processing Record 17  of Set 6 | torbat-e heydariyeh.
# Processing Record 18  of Set 6 | rayside-balfour.
# City not found...skipping rayside-balfour.
# Processing Record 19  of Set 6 | paita.
# Processing Record 20  of Set 6 | lazaro cardenas.
# Processing Record 21  of Set 6 | turabah.
# Processing Record 22  of Set 6 | launceston.
# Processing Record 23  of Set 6 | borovichi.
# Processing Record 24  of Set 6 | gagliano del capo.
# Processing Record 25  of Set 6 | susuman.
# Processing Record 26  of Set 6 | sovet.
# Processing Record 27  of Set 6 | cabo san lucas.
# Processing Record 28  of Set 6 | flying fish cove.
# Processing Record 29  of Set 6 | sadovoye.
# Processing Record 30  of Set 6 | manokwari.
# Processing Record 31  of Set 6 | zhezqazghan.
# Processing Record 32  of Set 6 | egilsstadir.
# Processing Record 33  of Set 6 | mount gambier.
# Processing Record 34  of Set 6 | nyurba.
# Processing Record 35  of Set 6 | haiku-pauwela.
# Processing Record 36  of Set 6 | berrouaghia.
# Processing Record 37  of Set 6 | hamilton.
# Processing Record 38  of Set 6 | kidal.
# Processing Record 39  of Set 6 | vernon.
# Processing Record 40  of Set 6 | kashiwazaki.
# Processing Record 41  of Set 6 | plouzane.
# Processing Record 42  of Set 6 | wanning.
# Processing Record 43  of Set 6 | tommot.
# Processing Record 44  of Set 6 | adh dhibiyah.
# City not found...skipping adh dhibiyah.
# Processing Record 45  of Set 6 | nova vicosa.
# Processing Record 46  of Set 6 | kyren.
# Processing Record 47  of Set 6 | isangel.
# Processing Record 48  of Set 6 | trairi.
# Processing Record 49  of Set 6 | ahau.
# City not found...skipping ahau.
# Processing Record 0  of Set 7 | choele choel.
# Processing Record 1  of Set 7 | camana.
# Processing Record 2  of Set 7 | isabela.
# Processing Record 3  of Set 7 | fort bragg.
# Processing Record 4  of Set 7 | nguigmi.
# Processing Record 5  of Set 7 | anna regina.
# Processing Record 6  of Set 7 | lata.
# Processing Record 7  of Set 7 | uzgen.
# Processing Record 8  of Set 7 | igarka.
# Processing Record 9  of Set 7 | elizabethtown.
# Processing Record 10  of Set 7 | lodwar.
# Processing Record 11  of Set 7 | mossel bay.
# Processing Record 12  of Set 7 | villa de soto.
# Processing Record 13  of Set 7 | fuwwah.
# Processing Record 14  of Set 7 | ta'izz.
# Processing Record 15  of Set 7 | port-gentil.
# Processing Record 16  of Set 7 | darwin.
# Processing Record 17  of Set 7 | elkhorn.
# Processing Record 18  of Set 7 | akom ii.
# Processing Record 19  of Set 7 | kyosai.
# Processing Record 20  of Set 7 | freetown.
# Processing Record 21  of Set 7 | coahuayana de hidalgo.
# Processing Record 22  of Set 7 | petropavlovsk-kamchatsky.
# Processing Record 23  of Set 7 | waingapu.
# Processing Record 24  of Set 7 | grand gaube.
# Processing Record 25  of Set 7 | kete krachi.
# Processing Record 26  of Set 7 | happy valley-goose bay.
# Processing Record 27  of Set 7 | pindushi.
# Processing Record 28  of Set 7 | pandan.
# Processing Record 29  of Set 7 | ta`u.
# Processing Record 30  of Set 7 | chonchi.
# Processing Record 31  of Set 7 | ratia.
# Processing Record 32  of Set 7 | callao.
# Processing Record 33  of Set 7 | prince rupert.
# Processing Record 34  of Set 7 | san antonio de pale.
# Processing Record 35  of Set 7 | taro.
# Processing Record 36  of Set 7 | ar ruways.
# Processing Record 37  of Set 7 | vanimo.
# Processing Record 38  of Set 7 | nuuk.
# Processing Record 39  of Set 7 | remire-montjoly.
# Processing Record 40  of Set 7 | nagqu.
# Processing Record 41  of Set 7 | kanel.
# Processing Record 42  of Set 7 | astorga.
# Processing Record 43  of Set 7 | tanjung pinang.
# Processing Record 44  of Set 7 | challapata.
# Processing Record 45  of Set 7 | burang.
# Processing Record 46  of Set 7 | sambava.
# Processing Record 47  of Set 7 | amarpatan.
# Processing Record 48  of Set 7 | ambilobe.
# Processing Record 49  of Set 7 | kargasok.
# Processing Record 0  of Set 8 | crane.
# Processing Record 1  of Set 8 | saint-joseph.
# Processing Record 2  of Set 8 | tamanrasset.
# Processing Record 3  of Set 8 | pocora.
# Processing Record 4  of Set 8 | itoman.
# Processing Record 5  of Set 8 | boda.
# Processing Record 6  of Set 8 | ambalangoda.
# Processing Record 7  of Set 8 | sao raimundo nonato.
# Processing Record 8  of Set 8 | butte.
# Processing Record 9  of Set 8 | seogwipo.
# City not found...skipping seogwipo.
# Processing Record 10  of Set 8 | el nido.
# Processing Record 11  of Set 8 | severnoye.
# Processing Record 12  of Set 8 | nizhniy kuranakh.
# Processing Record 13  of Set 8 | el alto.
# Processing Record 14  of Set 8 | mount pearl.
# Processing Record 15  of Set 8 | gloria.
# Processing Record 16  of Set 8 | sumperk.
# Processing Record 17  of Set 8 | campbellton.
# Processing Record 18  of Set 8 | cockburn town.
# Processing Record 19  of Set 8 | lubang.
# Processing Record 20  of Set 8 | goz beida.
# Processing Record 21  of Set 8 | island harbour.
# Processing Record 22  of Set 8 | choyr.
# Processing Record 23  of Set 8 | tamala.
# Processing Record 24  of Set 8 | boksitogorsk.
# Processing Record 25  of Set 8 | nichinan.
# Processing Record 26  of Set 8 | huarmey.
# Processing Record 27  of Set 8 | saint-pierre.
# Processing Record 28  of Set 8 | rikaze.
# Processing Record 29  of Set 8 | lensk.
# Processing Record 30  of Set 8 | svetlyy.
# Processing Record 31  of Set 8 | hammerfest.
# Processing Record 32  of Set 8 | shevchenko.
# Processing Record 33  of Set 8 | hailar.
# Processing Record 34  of Set 8 | koulamoutou.
# Processing Record 35  of Set 8 | mishelevka.
# Processing Record 36  of Set 8 | livingston.
# Processing Record 37  of Set 8 | alto araguaia.
# Processing Record 38  of Set 8 | general villegas.
# Processing Record 39  of Set 8 | san cristobal.
# Processing Record 40  of Set 8 | the pas.
# Processing Record 41  of Set 8 | sigli.
# Processing Record 42  of Set 8 | rabah.
# Processing Record 43  of Set 8 | holmen.
# Processing Record 44  of Set 8 | wotho.
# Processing Record 45  of Set 8 | bel ombre.
# Processing Record 46  of Set 8 | xilin hot.
# Processing Record 47  of Set 8 | kon tum.
# Processing Record 48  of Set 8 | sonsorol village.
# City not found...skipping sonsorol village.
# Processing Record 49  of Set 8 | egersund.
# Processing Record 0  of Set 9 | usogorsk.
# Processing Record 1  of Set 9 | kalix.
# Processing Record 2  of Set 9 | palmer.
# Processing Record 3  of Set 9 | saipan.
# Processing Record 4  of Set 9 | sungai raya.
# Processing Record 5  of Set 9 | mega.
# Processing Record 6  of Set 9 | undurkhaan.
# Processing Record 7  of Set 9 | barcelos.
# Processing Record 8  of Set 9 | mar del plata.
# Processing Record 9  of Set 9 | lerwick.
# Processing Record 10  of Set 9 | nouadhibou.
# Processing Record 11  of Set 9 | geneina.
# Processing Record 12  of Set 9 | shohimardon.
# Processing Record 13  of Set 9 | luxeuil-les-bains.
# Processing Record 14  of Set 9 | sao felix do xingu.
# Processing Record 15  of Set 9 | kapa'a.
# Processing Record 16  of Set 9 | petrovsk.
# Processing Record 17  of Set 9 | aykhal.
# Processing Record 18  of Set 9 | aquin.
# Processing Record 19  of Set 9 | vyaz'ma.
# Processing Record 20  of Set 9 | morehead city.
# Processing Record 21  of Set 9 | constitucion.
# Processing Record 22  of Set 9 | lubango.
# Processing Record 23  of Set 9 | ishigaki.
# Processing Record 24  of Set 9 | ribeira brava.
# Processing Record 25  of Set 9 | san andres.
# Processing Record 26  of Set 9 | uturoa.
# Processing Record 27  of Set 9 | skovorodino.
# Processing Record 28  of Set 9 | puerto san carlos.
# City not found...skipping puerto san carlos.
# Processing Record 29  of Set 9 | sanctuary point.
# Processing Record 30  of Set 9 | visby.
# Processing Record 31  of Set 9 | khandyga.
# Processing Record 32  of Set 9 | gembu.
# Processing Record 33  of Set 9 | cascais.
# Processing Record 34  of Set 9 | biloxi.
# Processing Record 35  of Set 9 | rodolfo sanchez taboada.
# Processing Record 36  of Set 9 | kerikeri.
# Processing Record 37  of Set 9 | innoshima.
# Processing Record 38  of Set 9 | devinuwara.
# City not found...skipping devinuwara.
# Processing Record 39  of Set 9 | konduga.
# Processing Record 40  of Set 9 | cill airne.
# Processing Record 41  of Set 9 | palikir - national government center.
# Processing Record 42  of Set 9 | chinde.
# Processing Record 43  of Set 9 | viqueque.
# Processing Record 44  of Set 9 | oranjemund.
# Processing Record 45  of Set 9 | nadi.
# Processing Record 46  of Set 9 | slave lake.
# Processing Record 47  of Set 9 | al-`ula.
# City not found...skipping al-`ula.
# Processing Record 48  of Set 9 | olovyannaya.
# Processing Record 49  of Set 9 | ghat.
# Processing Record 0  of Set 10 | caibarien.
# Processing Record 1  of Set 10 | arno.
# Processing Record 2  of Set 10 | sorong.
# Processing Record 3  of Set 10 | ljusdal.
# Processing Record 4  of Set 10 | westport.
# Processing Record 5  of Set 10 | tabou.
# Processing Record 6  of Set 10 | tilcara.
# Processing Record 7  of Set 10 | markovo.
# Processing Record 8  of Set 10 | kavieng.
# Processing Record 9  of Set 10 | chadron.
# Processing Record 10  of Set 10 | namsos.
# Processing Record 11  of Set 10 | lichuan.
# Processing Record 12  of Set 10 | balqash.
# Processing Record 13  of Set 10 | akureyri.
# Processing Record 14  of Set 10 | timbuktu.
# Processing Record 15  of Set 10 | bathsheba.
# Processing Record 16  of Set 10 | darhan.
# Processing Record 17  of Set 10 | caazapa.
# Processing Record 18  of Set 10 | ulladulla.
# Processing Record 19  of Set 10 | aioun.
# Processing Record 20  of Set 10 | antalaha.
# Processing Record 21  of Set 10 | zhanaozen.
# Processing Record 22  of Set 10 | kothi.
# Processing Record 23  of Set 10 | broome.
# Processing Record 24  of Set 10 | kuanda.
# Processing Record 25  of Set 10 | tsiombe.
# Processing Record 26  of Set 10 | yangor.
# City not found...skipping yangor.
# Processing Record 27  of Set 10 | forster.
# Processing Record 28  of Set 10 | tateyama.
# Processing Record 29  of Set 10 | tucupita.
# Processing Record 30  of Set 10 | juan griego.
# Processing Record 31  of Set 10 | sept-iles.
# Processing Record 32  of Set 10 | iquique.
# Processing Record 33  of Set 10 | massaguet.
# Processing Record 34  of Set 10 | san julian.
# Processing Record 35  of Set 10 | madang.
# Processing Record 36  of Set 10 | okhotsk.
# Processing Record 37  of Set 10 | farrokh shahr.
# Processing Record 38  of Set 10 | port saint john's.
# Processing Record 39  of Set 10 | somero.
# Processing Record 40  of Set 10 | walvis bay.
# Processing Record 41  of Set 10 | carmo do rio verde.
# Processing Record 42  of Set 10 | chibougamau.
# Processing Record 43  of Set 10 | lethem.
# Processing Record 44  of Set 10 | cat ba.
# City not found...skipping cat ba.
# Processing Record 45  of Set 10 | tobi village.
# City not found...skipping tobi village.
# Processing Record 46  of Set 10 | freeport.
# Processing Record 47  of Set 10 | ellsworth.
# Processing Record 48  of Set 10 | bouznika.
# Processing Record 49  of Set 10 | taulaga.
# Processing Record 0  of Set 11 | lagunas.
# Processing Record 1  of Set 11 | harper.
# Processing Record 2  of Set 11 | mpongwe.
# Processing Record 3  of Set 11 | puerto aysen.
# Processing Record 4  of Set 11 | luderitz.
# Processing Record 5  of Set 11 | gusinoozyorsk.
# Processing Record 6  of Set 11 | hue.
# Processing Record 7  of Set 11 | masterton.
# Processing Record 8  of Set 11 | mangrol.
# Processing Record 9  of Set 11 | taoudenni.
# Processing Record 10  of Set 11 | derzhavinsk.
# Processing Record 11  of Set 11 | west bay.
# Processing Record 12  of Set 11 | la palma.
# Processing Record 13  of Set 11 | quelimane.
# Processing Record 14  of Set 11 | kingston.
# Processing Record 15  of Set 11 | alofi.
# Processing Record 16  of Set 11 | cooper's town.
# Processing Record 17  of Set 11 | coquimbo.
# Processing Record 18  of Set 11 | fuglafjordur.
# Processing Record 19  of Set 11 | vialonga.
# Processing Record 20  of Set 11 | lochem.
# Processing Record 21  of Set 11 | nova russas.
# Processing Record 22  of Set 11 | sakaiminato.
# Processing Record 23  of Set 11 | los alamos.
# Processing Record 24  of Set 11 | bandar-e lengeh.
# Processing Record 25  of Set 11 | tolanaro.
# Processing Record 26  of Set 11 | cumbal.
# Processing Record 27  of Set 11 | harstad.
# Processing Record 28  of Set 11 | yuzhno-kurilsk.
# Processing Record 29  of Set 11 | lesnoy.
# Processing Record 30  of Set 11 | soio.
# Processing Record 31  of Set 11 | miguelopolis.
# Processing Record 32  of Set 11 | kamloops.
# Processing Record 33  of Set 11 | mormugao.
# Processing Record 34  of Set 11 | es castell.
# Processing Record 35  of Set 11 | barra.
# Processing Record 36  of Set 11 | mahina.
# Processing Record 37  of Set 11 | yarrawonga.
# Processing Record 38  of Set 11 | xining.
# Processing Record 39  of Set 11 | aldinga beach.
# Processing Record 40  of Set 11 | general mosconi.
# Processing Record 41  of Set 11 | nyandoma.
# Processing Record 42  of Set 11 | sinop.
# Processing Record 43  of Set 11 | vostochnyy.
# Processing Record 44  of Set 11 | i-n-salah.
# Processing Record 45  of Set 11 | papao.
# Processing Record 46  of Set 11 | gotsucho.
# Processing Record 47  of Set 11 | berdigestyakh.
# Processing Record 48  of Set 11 | roma.
# Processing Record 49  of Set 11 | puerto baquerizo moreno.
# Processing Record 0  of Set 12 | timaru.
# Processing Record 1  of Set 12 | fernie.
# Processing Record 2  of Set 12 | sandnessjoen.
# Processing Record 3  of Set 12 | portel.
# Processing Record 4  of Set 12 | natal.
# Processing Record 5  of Set 12 | ankang.
# Processing Record 6  of Set 12 | cururupu.
# Processing Record 7  of Set 12 | santa helena.
# Processing Record 8  of Set 12 | harrison.
# Processing Record 9  of Set 12 | fale old settlement.
# Processing Record 10  of Set 12 | kruisfontein.
# Processing Record 11  of Set 12 | zeya.
# Processing Record 12  of Set 12 | nao me toque.
# Processing Record 13  of Set 12 | aiquile.
# Processing Record 14  of Set 12 | llanes.
# Processing Record 15  of Set 12 | shitanjing.
# Processing Record 16  of Set 12 | mpika.
# Processing Record 17  of Set 12 | praia da vitoria.
# Processing Record 18  of Set 12 | searcy.
# Processing Record 19  of Set 12 | portland.
# Processing Record 20  of Set 12 | road town.
# Processing Record 21  of Set 12 | atherton.
# Processing Record 22  of Set 12 | sinabang.
# Processing Record 23  of Set 12 | buala.
# Processing Record 24  of Set 12 | grand falls-windsor.
# Processing Record 25  of Set 12 | kushiro.
# Processing Record 26  of Set 12 | albertina.
# Processing Record 27  of Set 12 | al qadarif.
# Processing Record 28  of Set 12 | raduzhny.
# Processing Record 29  of Set 12 | awjilah.
# Processing Record 30  of Set 12 | marang.
# Processing Record 31  of Set 12 | manadhoo.
# Processing Record 32  of Set 12 | madera.
# Processing Record 33  of Set 12 | tulln.
# Processing Record 34  of Set 12 | port moresby.
# Processing Record 35  of Set 12 | fonadhoo.
# City not found...skipping fonadhoo.
# Processing Record 36  of Set 12 | borodulikha.
# Processing Record 37  of Set 12 | tol'yatti.
# Processing Record 38  of Set 12 | selkirk.
# Processing Record 39  of Set 12 | kunhegyes.
# Processing Record 40  of Set 12 | mili.
# Processing Record 41  of Set 12 | ballina.
# Processing Record 42  of Set 12 | birao.
# Processing Record 43  of Set 12 | kittila.
# Processing Record 44  of Set 12 | andergrove.
# Processing Record 45  of Set 12 | geraldton.
# Processing Record 46  of Set 12 | ha giang.
# Processing Record 47  of Set 12 | carboneras.
# Processing Record 48  of Set 12 | greenland.
# Processing Record 49  of Set 12 | vargarda.
# Processing Record 0  of Set 13 | mabaruma.
# Processing Record 1  of Set 13 | bambari.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Data Count
weather_df.count()
# Out:
# City                602
# Country             602
# Date                602
# Latitude            602
# Longitude           602
# Cloudiness (%)      602
# Humidity (%)        602
# Max Temp (F)        602
# Wind Speed (mph)    602
# dtype: int64

# %%
# Display DataFrame
weather_df.head()
# Out:
#           City Country                 Date Latitude Longitude Cloudiness (%)  \
# 0   fuvahmulah
# 1  zhangjiakou      CN  2024-04-25 22:17:54    40.81  114.8794            100
# 2     muzayri'
# 3     clorinda      AR  2024-04-25 22:17:54 -25.2848  -57.7185             42
# 4    papatowai      NZ  2024-04-25 22:09:29 -46.5619  169.4708             80
#
#   Humidity (%) Max Temp (F) Wind Speed (mph)
# 0
# 1           27       72.896             0.88
# 2
# 3           86       81.032             2.67
# 4           79       46.418             7.06

# %%
# Convert data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.93x + 92.92
# The r-squared is: -0.8788424314293743
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.67x + 84.81
# The r-squared is: 0.7485715306161477
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.21x + 61.23
# The r-squared is: 0.18479925401476968
# The regression does not display much of a correlation between the data sets.

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.31x + 81.68
# The r-squared is: 0.24948636941307473
# The regression does not display much of a correlation between the data sets.

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.33x + 48.29
# The r-squared is: 0.16632746746910687
# The regression does not display much of a correlation between the data sets.

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.12x + 62.44
# The r-squared is: 0.046834135040675226
# The regression does not display much of a correlation between the data sets.

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.0x + 3.54
# The r-squared is: -0.011453668189724552
# The regression does not display much of a correlation between the data sets.

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.04x + 2.69
# The r-squared is: -0.23583547372128127
# The regression does not display much of a correlation between the data sets.
